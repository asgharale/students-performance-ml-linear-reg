# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np


df = pd.read_csv('student-mat.csv', sep=';')

label = 'G3'

x = np.array(df[['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']])
y = np.array(df[label])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

linear = LinearRegression()
linear.fit(x_train, y_train)

predictions = linear.predict(x_test)


acc = linear.score(x_test, y_test)

print("ضریب: ", linear.coef_)
print("رهگیری: ", linear.intercept_)

print()
print()
print(acc)
for i in range(len(predictions)):
    print(predictions[i], x_test[i], y_test[i])
# Out:
# ضریب:  [-0.13607869  0.1594511  -0.10819915  0.13623222 -0.20565003 -0.171684
#   0.40631857  0.01086024 -0.10246988 -0.13003278  0.1833968   0.01837639
#   0.04547382  0.15738853  0.97441378]
# رهگیری:  -1.2101579848067594
#
#
# 0.7942235959129211
# 9.14319318375935 [16  3  3  1  2  0  4  3  2  1  2  5  4  6 10] 10
# 16.28614833408734 [16  4  2  1  2  0  4  2  3  1  1  5  2 15 16] 16
# 11.669215936143836 [16  3  2  2  1  1  4  5  2  1  1  2 16 12 11] 12
# 12.231282533917485 [18  3  2  3  1  0  4  4  1  3  4  5  0 11 12] 10
# 8.577398879376107 [16  1  1  4  1  0  5  5  5  5  5  5  6 10  8] 11
# 7.416006372839638 [15  2  3  1  2  0  4  4  4  1  1  1  2 11  8] 8
# 11.896601363538355 [18  3  2  2  2  0  4  1  1  1  1  5 75 10  9] 9
# 11.796781907047992 [15  4  2  2  1  1  5  5  5  3  4  5  6 11 11] 10
# 16.908298763218735 [16  4  4  1  3  0  4  4  3  1  1  4  0 16 17] 17
# 7.95874958116052 [16  2  1  1  2  0  4  3  5  1  1  5  2  8  9] 10
# 12.211138546794668 [15  2  2  1  4  0  4  3  4  1  1  4  6 11 13] 14
# 9.168212002996967 [17  4  4  1  2  0  4  5  5  1  3  2 14 11  9] 9
# 11.616065723397705 [15  4  4  1  4  0  1  3  3  5  5  3  4 13 13] 12
# 0.2463538138848962 [15  3  4  4  2  0  5  3  3  1  1  5  0  9  0] 0
# 9.452887282490517 [16  2  2  2  4  0  5  3  5  1  1  5  6 10 10] 11
# 11.599042133913573 [17  2  1  1  1  0  4  4  2  2  4  5  0  8 12] 12
# 4.962808229554132 [18  4  2  2  1  1  5  4  3  4  3  3 14  6  5] 5
# 16.150369751673715 [15  4  2  1  1  0  2  2  4  2  4  1  4 15 16] 15
# 16.456909262577955 [18  1  1  2  3  0  5  3  2  1  1  4  0 18 16] 16
# 7.9727564375695525 [17  1  1  2  1  1  4  4  4  1  2  5  2  7  9] 8
# 8.910630771450444 [18  4  4  1  2  1  4  3  3  2  2  2  0 10 10] 0
# 11.742541375344148 [18  4  2  1  2  0  4  3  2  1  4  5 11 12 11] 11
# 8.722177508942165 [17  4  3  2  2  0  4  4  4  4  4  4  4 10  9] 9
# 9.655416537905262 [17  2  1  2  3  0  3  2  3  1  2  3 10 12 10] 12
# 8.385141983478679 [20  2  2  1  2  2  5  5  4  4  5  4 11  9  9] 9
# 11.669492952065813 [19  2  3  1  3  1  4  1  2  1  1  3 40 13 11] 11
# 8.728450239577338 [15  2  1  4  1  3  4  5  5  2  5  5  0  8  9] 10
# 13.963900751097967 [15  4  2  1  3  0  3  2  2  1  1  5  2 15 14] 15
# 12.9597013079475 [17  4  4  2  2  0  4  3  3  1  2  5  4 12 13] 13
# 14.30351384188175 [16  4  4  1  1  0  5  3  4  1  2  1  6 11 14] 14
# 14.450987571657855 [17  4  3  1  2  0  5  2  2  1  2  5 23 13 13] 13
# 15.56792448927936 [17  3  1  2  1  0  2  4  5  3  4  2  3 14 16] 16
# 5.713301887872695 [17  1  1  3  1  1  5  2  1  1  2  1  0  7  6] 0
# 13.48946764840627 [18  3  2  2  3  0  5  4  2  1  1  4  8 14 13] 14
# 5.108771318058897 [16  3  1  1  2  0  3  3  3  2  3  2  4  7  6] 6
# 14.50534930720645 [17  2  4  1  2  0  4  3  2  1  1  5  0 14 15] 15
# 15.91604865615707 [16  4  2  1  2  0  4  5  1  1  3  5  2 15 15] 16
# 9.054930722289027 [17  2  4  2  2  0  4  3  3  1  1  1  2 10 10] 10
# 11.868253766961484 [18  4  4  3  2  0  3  2  2  4  2  5 10 14 12] 11
# -1.3243084326587238 [18  2  1  2  3  0  4  4  4  1  1  3  0  7  0] 0

# %%
# Out:
# ضریب:  [-0.18926738  0.09948971 -0.15494152  0.14441003 -0.10005825 -0.21613395
#   0.35301727  0.0630675   0.04072399 -0.11954431  0.10598304  0.06374101
#   0.04193896  0.16255543  0.98732535]
# رهگیری:  -0.8808385287475158
#
#
# 0.8521135782801977
# 13.759267211169137 [16  1  1  1  1  0  3  4  4  3  3  1  2 14 14] 13
# 8.07015235022189 [18  2  2  2  4  0  4  4  4  1  1  4  0 10  9] 0
# 5.866624281133457 [19  1  1  3  2  3  5  4  4  3  3  2  8  8  7] 8
# 11.152785661743149 [19  2  1  1  3  1  4  3  4  1  3  3  4 11 12] 11
# 8.14682349734435 [16  4  2  1  1  0  4  3  3  3  4  3 10 10  8] 9
# 13.878708846253907 [18  4  4  1  1  0  1  4  2  2  2  1  5 16 15] 16
# 13.472736269770973 [17  1  2  1  2  0  3  5  2  2  2  1  2 15 14] 14
# 18.975511817349066 [15  4  4  1  2  0  4  3  3  1  1  5  2 19 18] 18
# 10.421213756476643 [17  2  3  2  2  0  4  4  3  1  1  3  2 11 11] 10
# 20.483507077661947 [15  4  4  1  1  0  5  5  3  1  1  4  6 18 19] 19
# 14.506476455599914 [16  4  3  2  1  0  3  3  3  1  1  4  2 11 15] 15
# 17.126643118218922 [16  4  4  1  3  0  4  4  3  1  1  4  0 16 17] 17
# 7.056725695535677 [19  1  1  3  1  1  4  4  4  3  3  5  4  8  8] 8
# 11.298804790165693 [16  1  2  1  1  0  3  3  3  1  2  3  2 11 12] 11
# 10.809023416435922 [15  4  4  1  2  0  5  4  2  3  4  5  0  9 11] 12
# -0.6782104424547701 [16  1  2  2  1  1  4  4  4  2  4  5  0  7  0] 0
# 11.32192251818738 [17  4  3  2  2  0  4  5  5  1  3  2  4 13 11] 11
# 8.22763970295175 [16  4  3  1  3  0  5  3  5  1  1  3  0  7  9] 8
# 5.865552187990002 [17  2  3  2  1  0  3  3  3  1  4  3  3  7  7] 8
# 9.776233941425764 [16  3  3  3  2  0  5  3  2  1  1  4  4  8 10] 10
# 12.793967550419783 [15  2  2  1  4  0  4  3  4  1  1  4  6 11 13] 14
# 15.23782075583651 [17  3  2  2  2  0  4  4  4  1  3  1  2 14 15] 15
# 9.046347342741086 [17  2  2  1  2  0  5  4  5  1  2  5  4 10  9] 11
# 7.225676765500117 [18  2  2  1  4  0  4  5  5  2  4  5  2  9  8] 8
# 10.234830309152834 [15  4  4  1  3  0  4  2  2  1  1  5  2  9 11] 11
# 14.654599870782238 [15  4  2  1  3  0  5  3  3  1  3  1  4 13 14] 14
# 4.082788718626719 [17  3  3  1  2  0  4  3  4  1  4  4  4  6  5] 6
# 10.728341446507399 [15  3  3  1  4  0  4  3  3  1  1  4 10 10 11] 11
# 9.126946208758008 [18  2  3  1  3  0  4  3  3  1  2  3  4 11 10] 10
# -1.1121833414778033 [18  2  1  2  3  0  4  4  4  1  1  3  0  7  0] 0
# 14.934721146769455 [16  0  2  1  1  0  4  3  2  2  4  5  0 13 15] 15
# 4.1073388280615415 [18  4  4  3  1  0  4  4  3  2  2  5  7  6  5] 6
# 5.879962361212124 [16  4  4  1  2  0  4  1  3  3  5  5 18  8  6] 7
# 5.994741119525118 [16  3  3  1  3  0  4  3  3  1  3  4  0  7  7] 8
# 13.069322727367412 [18  3  2  1  3  0  5  4  3  2  3  1  7 13 13] 14
# 9.125569372391206 [18  1  1  2  1  0  3  3  2  1  2  3  4 10 10] 10
